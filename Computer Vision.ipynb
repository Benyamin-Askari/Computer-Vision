# %% [markdown]
# #1. Install Necessary Packages

# %%
# Install necessary packages
# !pip install ultralytics
# !pip install opencv-python
# !pip install ffmpeg-python
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.47-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cpu)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.12-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.47-py3-none-any.whl (898 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.8/898.8 kB 14.5 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.12-py3-none-any.whl (26 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, ultralytics-thop, ultralytics
# Successfully installed py-cpuinfo-9.0.0 ultralytics-8.3.47 ultralytics-thop-2.0.12
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting future (from ffmpeg-python)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 9.1 MB/s eta 0:00:00
# Installing collected packages: future, ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0 future-1.0.0

# %% [markdown]
# #2. Importing Libraries and Initializing the Model

# %% [markdown]
# Note:
#
# the below cell is to confirm that which Class ID corresponds to car to truck

# %%
from ultralytics import YOLO
import cv2
from google.colab import files
import os
from collections import deque

# Load the YOLO model (ensure the model file is correctly named and accessible)
model = YOLO("yolo11x.pt")  # Replace with your model path if different

# Verify class names and IDs
print("Model Classes and IDs:")
for class_id, class_name in model.names.items():
    print(f"ID {class_id}: {class_name}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11x.pt to 'yolo11x.pt'...
# 100%|██████████| 109M/109M [00:00<00:00, 282MB/s]
# Model Classes and IDs:
# ID 0: person
# ID 1: bicycle
# ID 2: car
# ID 3: motorcycle
# ID 4: airplane
# ID 5: bus
# ID 6: train
# ID 7: truck
# ID 8: boat
# ID 9: traffic light
# ID 10: fire hydrant
# ID 11: stop sign
# ID 12: parking meter
# ID 13: bench
# ID 14: bird
# ID 15: cat
# ID 16: dog
# ID 17: horse
# ID 18: sheep
# ID 19: cow
# ID 20: elephant
# ID 21: bear
# ID 22: zebra
# ID 23: giraffe
# ID 24: backpack
# ID 25: umbrella
# ID 26: handbag
# ID 27: tie
# ID 28: suitcase
# ID 29: frisbee
# ID 30: skis
# ID 31: snowboard
# ID 32: sports ball
# ID 33: kite
# ID 34: baseball bat
# ID 35: baseball glove
# ID 36: skateboard
# ID 37: surfboard
# ID 38: tennis racket
# ID 39: bottle
# ID 40: wine glass
# ID 41: cup
# ID 42: fork
# ID 43: knife
# ID 44: spoon
# ID 45: bowl
# ID 46: banana
# ID 47: apple
# ID 48: sandwich
# ID 49: orange
# ID 50: broccoli
# ID 51: carrot
# ID 52: hot dog
# ID 53: pizza
# ID 54: donut
# ID 55: cake
# ID 56: chair
# ID 57: couch
# ID 58: potted plant
# ID 59: bed
# ID 60: dining table
# ID 61: toilet
# ID 62: tv
# ID 63: laptop
# ID 64: mouse
# ID 65: remote
# ID 66: keyboard
# ID 67: cell phone
# ID 68: microwave
# ID 69: oven
# ID 70: toaster
# ID 71: sink
# ID 72: refrigerator
# ID 73: book
# ID 74: clock
# ID 75: vase
# ID 76: scissors
# ID 77: teddy bear
# ID 78: hair drier
# ID 79: toothbrush

# %% [markdown]
# Class ID "2" belongs to car and Class ID "7" belongs to truck

# %% [markdown]
# #3. Set Input and Output Video Paths

# %% [markdown]
# Specifying the paths to the input and output videos

# %%
# Path to the input video
input_video_path = "/content/vehicle-counting.mp4"  # Replace with your video path

# Path to the output video
output_video_path = "/content/vehicle-counting-annotated.mp4"

# %% [markdown]
# #4. Initialize Video Capture and Writer

# %% [markdown]
# Setting up video capture for reading, and video writer for saving the annotated video

# %%
# Create a Video Capture Object
cap = cv2.VideoCapture(input_video_path)

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

print(f"Video Properties:\nWidth: {frame_width}\nHeight: {frame_height}\nFPS: {fps}\nTotal Frames: {total_frames}")

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # 'mp4v' is generally reliable for MP4
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))
# Out:
# Video Properties:
# Width: 3840
# Height: 2160
# FPS: 25.0
# Total Frames: 538

# %% [markdown]
# #5. Initialize Counters and Tracking Structures

# %% [markdown]
# Setting up counters for categorizing counter based on direction and vehicle type

# %%
# Initialize vehicle counters and line information
car_count_in = 0
car_count_out = 0
truck_count_in = 0
truck_count_out = 0
line_position = None

# Store tracked object IDs and their previous positions
crossed_ids = set()
track_positions = {}

# %% [markdown]
# #6. Define Helper Functions

# %% [markdown]
# Implementing the functions to draw the counting line, determining movement direction, and filtering desired classes based on class IDs (cars and trucks in this case)

# %%
# Function to draw the counting line
def draw_counting_line(frame):
    global line_position
    height, width = frame.shape[:2]
    if line_position is None:  # Set the line position only once
        line_position = height - 400  # Line 400 pixels from the bottom
    cv2.line(frame, (0, line_position), (width, line_position), (0, 255, 0), 2)

# Function to determine direction
def get_direction(track_id, current_center_y):
    previous_center_y = track_positions.get(track_id, None)
    if previous_center_y is None:
        return None  # Not enough information to determine direction
    if previous_center_y < line_position and current_center_y > line_position:
        return "down"  # Moving downwards (e.g., Out)
    elif previous_center_y > line_position and current_center_y < line_position:
        return "up"    # Moving upwards (e.g., In)
    else:
        return None  # No crossing or moving parallel

# Function to check if the class ID is desired (2 for car, 7 for truck)
def is_desired_class_id(class_id):
    desired_class_ids = [2, 7]  # 2: car, 7: truck
    return class_id in desired_class_ids

# %% [markdown]
# #7. Processing Video Frames

# %% [markdown]
# This section processes each frame, performs detection and tracking: then updates counts based on direction, and finally, annotates the frames

# %%
# Process video frames
frame_number = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break  # End of video

    frame_number += 1

    # Draw the counting line
    draw_counting_line(frame)

    # Run YOLO detection with ByteTrack tracking
    try:
        results = model.track(
            source=frame,
            persist=True,
            tracker="bytetrack.yaml",  # Ensure 'bytetrack.yaml' is present in the environment
            conf=0.25,  # Confidence threshold
            iou=0.5     # IoU threshold
        )
    except Exception as e:
        print(f"Error during model tracking at frame {frame_number}: {e}")
        continue  # Skip this frame

    # Process each detection
    if results[0].boxes:  # Ensure there are detections
        for box in results[0].boxes:
            # Extract bounding box, class ID, and unique track ID
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            class_id = int(box.cls)
            track_id = int(box.id)

            # Skip unwanted classes based on class ID
            if not is_desired_class_id(class_id):
                continue  # Skip this detection

            # Get the center point of the bounding box
            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2

            # Determine direction based on previous position
            direction = get_direction(track_id, center_y)

            # Update the previous position
            track_positions[track_id] = center_y

            # Check if the object has crossed the line and hasn't been counted yet
            if track_id not in crossed_ids and direction is not None:
                crossed_ids.add(track_id)  # Mark object as counted
                if class_id == 2:  # Car
                    if direction == "down":
                        car_count_out += 1
                    elif direction == "up":
                        car_count_in += 1
                elif class_id == 7:  # Truck
                    if direction == "down":
                        truck_count_out += 1
                    elif direction == "up":
                        truck_count_in += 1

            # Assign class name based on class ID
            if class_id == 2:
                class_name = "Car"
                color = (255, 0, 0)  # Blue for cars
            elif class_id == 7:
                class_name = "Truck"
                color = (0, 0, 255)  # Red for trucks
            else:
                class_name = "Unknown"
                color = (0, 255, 255)  # Yellow for other desired classes

            # Draw bounding box and label on the frame
            label = f"{class_name} ID:{track_id}"
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, label, (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

    # Display the vehicle counts on the frame
    cv2.putText(frame, f"Cars In: {car_count_in}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    cv2.putText(frame, f"Cars Out: {car_count_out}", (10, 70),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    cv2.putText(frame, f"Trucks In: {truck_count_in}", (10, 110),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.putText(frame, f"Trucks Out: {truck_count_out}", (10, 150),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Write the annotated frame to the output video
    out.write(frame)

    # Optional: Print progress every 100 frames
    if frame_number % 100 == 0:
        print(f"Processed {frame_number}/{total_frames} frames.")

print("Processing complete.")

# Release video writer and capture
out.release()
cap.release()
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Collecting lap>=0.5.12
#   Downloading lap-0.5.12-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from lap>=0.5.12) (1.26.4)
# Downloading lap-0.5.12-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 24.5 MB/s eta 0:00:00
# Installing collected packages: lap
# Successfully installed lap-0.5.12
#
# requirements: AutoUpdate success ✅ 1.8s, installed 1 package: ['lap>=0.5.12']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# 0: 384x640 4 cars, 1 truck, 716.0ms
# Speed: 2.5ms preprocess, 716.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 605.3ms
# Speed: 2.4ms preprocess, 605.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 595.8ms
# Speed: 2.3ms preprocess, 595.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 569.8ms
# Speed: 2.4ms preprocess, 569.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 625.9ms
# Speed: 2.5ms preprocess, 625.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 620.8ms
# Speed: 2.5ms preprocess, 620.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 540.8ms
# Speed: 2.7ms preprocess, 540.8ms inference, 54.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 537.5ms
# Speed: 2.4ms preprocess, 537.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 619.9ms
# Speed: 2.6ms preprocess, 619.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 602.8ms
# Speed: 2.3ms preprocess, 602.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 622.1ms
# Speed: 2.4ms preprocess, 622.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 621.7ms
# Speed: 2.4ms preprocess, 621.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 615.0ms
# Speed: 2.6ms preprocess, 615.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 571.6ms
# Speed: 2.4ms preprocess, 571.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 630.1ms
# Speed: 2.5ms preprocess, 630.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 612.3ms
# Speed: 2.3ms preprocess, 612.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 549.8ms
# Speed: 2.6ms preprocess, 549.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 538.7ms
# Speed: 2.4ms preprocess, 538.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 621.0ms
# Speed: 2.3ms preprocess, 621.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 593.6ms
# Speed: 2.3ms preprocess, 593.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 556.0ms
# Speed: 2.2ms preprocess, 556.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 558.3ms
# Speed: 2.5ms preprocess, 558.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 566.3ms
# Speed: 2.5ms preprocess, 566.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 553.7ms
# Speed: 2.3ms preprocess, 553.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 597.9ms
# Speed: 2.6ms preprocess, 597.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 564.4ms
# Speed: 2.4ms preprocess, 564.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 644.8ms
# Speed: 2.5ms preprocess, 644.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 608.7ms
# Speed: 3.6ms preprocess, 608.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 591.3ms
# Speed: 2.3ms preprocess, 591.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 614.9ms
# Speed: 2.9ms preprocess, 614.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 621.4ms
# Speed: 2.4ms preprocess, 621.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 622.1ms
# Speed: 3.0ms preprocess, 622.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 622.9ms
# Speed: 2.6ms preprocess, 622.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 622.9ms
# Speed: 2.7ms preprocess, 622.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 628.6ms
# Speed: 2.8ms preprocess, 628.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 596.8ms
# Speed: 2.7ms preprocess, 596.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 559.7ms
# Speed: 2.5ms preprocess, 559.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 554.6ms
# Speed: 2.9ms preprocess, 554.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 580.1ms
# Speed: 2.9ms preprocess, 580.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 567.8ms
# Speed: 2.8ms preprocess, 567.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 659.5ms
# Speed: 2.6ms preprocess, 659.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 622.3ms
# Speed: 2.9ms preprocess, 622.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 681.9ms
# Speed: 2.8ms preprocess, 681.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 635.2ms
# Speed: 2.9ms preprocess, 635.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 573.4ms
# Speed: 2.9ms preprocess, 573.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 645.8ms
# Speed: 2.5ms preprocess, 645.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 625.4ms
# Speed: 2.6ms preprocess, 625.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 604.7ms
# Speed: 2.5ms preprocess, 604.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 619.3ms
# Speed: 2.8ms preprocess, 619.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 627.1ms
# Speed: 2.4ms preprocess, 627.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 572.2ms
# Speed: 3.0ms preprocess, 572.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 546.8ms
# Speed: 2.6ms preprocess, 546.8ms inference, 54.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 547.8ms
# Speed: 2.6ms preprocess, 547.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 549.0ms
# Speed: 2.6ms preprocess, 549.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 628.4ms
# Speed: 2.4ms preprocess, 628.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 561.6ms
# Speed: 2.4ms preprocess, 561.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 545.4ms
# Speed: 2.8ms preprocess, 545.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 568.0ms
# Speed: 2.4ms preprocess, 568.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 626.5ms
# Speed: 2.3ms preprocess, 626.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 615.4ms
# Speed: 2.7ms preprocess, 615.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 621.8ms
# Speed: 2.4ms preprocess, 621.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 606.4ms
# Speed: 2.3ms preprocess, 606.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 593.9ms
# Speed: 2.4ms preprocess, 593.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 642.0ms
# Speed: 3.6ms preprocess, 642.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 554.1ms
# Speed: 2.4ms preprocess, 554.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 552.9ms
# Speed: 2.5ms preprocess, 552.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 526.0ms
# Speed: 2.3ms preprocess, 526.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 563.8ms
# Speed: 2.7ms preprocess, 563.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 570.1ms
# Speed: 2.7ms preprocess, 570.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 567.7ms
# Speed: 2.5ms preprocess, 567.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 612.0ms
# Speed: 2.5ms preprocess, 612.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 549.6ms
# Speed: 2.8ms preprocess, 549.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 545.3ms
# Speed: 2.3ms preprocess, 545.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 616.7ms
# Speed: 2.3ms preprocess, 616.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 568.0ms
# Speed: 2.3ms preprocess, 568.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 548.8ms
# Speed: 2.4ms preprocess, 548.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 559.4ms
# Speed: 2.6ms preprocess, 559.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 594.5ms
# Speed: 2.5ms preprocess, 594.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 547.3ms
# Speed: 2.3ms preprocess, 547.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 575.4ms
# Speed: 2.5ms preprocess, 575.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 637.6ms
# Speed: 2.4ms preprocess, 637.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 621.4ms
# Speed: 2.5ms preprocess, 621.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 600.0ms
# Speed: 2.5ms preprocess, 600.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 534.0ms
# Speed: 2.5ms preprocess, 534.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 601.6ms
# Speed: 2.3ms preprocess, 601.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 618.9ms
# Speed: 2.3ms preprocess, 618.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 616.0ms
# Speed: 2.4ms preprocess, 616.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 1 fire hydrant, 622.9ms
# Speed: 2.6ms preprocess, 622.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 1 fire hydrant, 643.1ms
# Speed: 2.4ms preprocess, 643.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 628.7ms
# Speed: 2.4ms preprocess, 628.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 606.1ms
# Speed: 2.4ms preprocess, 606.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 fire hydrant, 647.1ms
# Speed: 2.6ms preprocess, 647.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 616.8ms
# Speed: 2.4ms preprocess, 616.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 fire hydrant, 613.7ms
# Speed: 2.4ms preprocess, 613.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 623.4ms
# Speed: 2.4ms preprocess, 623.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 599.8ms
# Speed: 2.3ms preprocess, 599.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 611.2ms
# Speed: 2.7ms preprocess, 611.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 612.0ms
# Speed: 2.4ms preprocess, 612.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 fire hydrant, 624.9ms
# Speed: 2.3ms preprocess, 624.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 632.5ms
# Speed: 2.5ms preprocess, 632.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed 100/538 frames.
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 579.6ms
# Speed: 2.5ms preprocess, 579.6ms inference, 53.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 628.1ms
# Speed: 2.3ms preprocess, 628.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 613.9ms
# Speed: 2.6ms preprocess, 613.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 617.8ms
# Speed: 2.8ms preprocess, 617.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 623.9ms
# Speed: 2.4ms preprocess, 623.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 603.8ms
# Speed: 2.5ms preprocess, 603.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 547.9ms
# Speed: 2.6ms preprocess, 547.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 546.6ms
# Speed: 2.4ms preprocess, 546.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 606.9ms
# Speed: 2.4ms preprocess, 606.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 607.2ms
# Speed: 2.3ms preprocess, 607.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 615.1ms
# Speed: 2.4ms preprocess, 615.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 613.7ms
# Speed: 2.4ms preprocess, 613.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 613.2ms
# Speed: 2.5ms preprocess, 613.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 631.6ms
# Speed: 2.4ms preprocess, 631.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 627.0ms
# Speed: 2.5ms preprocess, 627.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 543.4ms
# Speed: 2.3ms preprocess, 543.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 550.0ms
# Speed: 2.3ms preprocess, 550.0ms inference, 52.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 551.9ms
# Speed: 2.4ms preprocess, 551.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 550.3ms
# Speed: 2.4ms preprocess, 550.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 609.9ms
# Speed: 2.5ms preprocess, 609.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 605.6ms
# Speed: 2.4ms preprocess, 605.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 534.9ms
# Speed: 2.3ms preprocess, 534.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 604.1ms
# Speed: 2.5ms preprocess, 604.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 615.3ms
# Speed: 2.5ms preprocess, 615.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 640.8ms
# Speed: 2.4ms preprocess, 640.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 634.9ms
# Speed: 2.5ms preprocess, 634.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 610.1ms
# Speed: 2.5ms preprocess, 610.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 550.9ms
# Speed: 2.5ms preprocess, 550.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 555.3ms
# Speed: 2.5ms preprocess, 555.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 598.0ms
# Speed: 2.3ms preprocess, 598.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 615.6ms
# Speed: 2.5ms preprocess, 615.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 623.4ms
# Speed: 2.7ms preprocess, 623.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 611.0ms
# Speed: 2.5ms preprocess, 611.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 619.4ms
# Speed: 2.3ms preprocess, 619.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 625.0ms
# Speed: 2.3ms preprocess, 625.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 559.4ms
# Speed: 2.3ms preprocess, 559.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 588.9ms
# Speed: 2.5ms preprocess, 588.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 601.7ms
# Speed: 2.6ms preprocess, 601.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 554.8ms
# Speed: 2.5ms preprocess, 554.8ms inference, 54.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 626.5ms
# Speed: 2.5ms preprocess, 626.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 612.3ms
# Speed: 2.5ms preprocess, 612.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 548.2ms
# Speed: 2.5ms preprocess, 548.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 547.1ms
# Speed: 2.5ms preprocess, 547.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 614.2ms
# Speed: 2.6ms preprocess, 614.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 620.9ms
# Speed: 2.3ms preprocess, 620.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 614.5ms
# Speed: 2.4ms preprocess, 614.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 633.2ms
# Speed: 2.6ms preprocess, 633.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 550.4ms
# Speed: 2.4ms preprocess, 550.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 639.5ms
# Speed: 2.3ms preprocess, 639.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 637.9ms
# Speed: 2.5ms preprocess, 637.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 597.3ms
# Speed: 2.4ms preprocess, 597.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 548.7ms
# Speed: 2.4ms preprocess, 548.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 553.2ms
# Speed: 2.4ms preprocess, 553.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 598.2ms
# Speed: 2.5ms preprocess, 598.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 fire hydrant, 548.0ms
# Speed: 2.4ms preprocess, 548.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 558.8ms
# Speed: 2.4ms preprocess, 558.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 593.1ms
# Speed: 2.6ms preprocess, 593.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 615.7ms
# Speed: 2.3ms preprocess, 615.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 626.8ms
# Speed: 2.3ms preprocess, 626.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 571.0ms
# Speed: 2.4ms preprocess, 571.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 617.5ms
# Speed: 2.5ms preprocess, 617.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 606.8ms
# Speed: 2.4ms preprocess, 606.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 619.3ms
# Speed: 2.4ms preprocess, 619.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 633.4ms
# Speed: 2.4ms preprocess, 633.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 598.8ms
# Speed: 2.4ms preprocess, 598.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 613.9ms
# Speed: 2.4ms preprocess, 613.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 560.1ms
# Speed: 2.5ms preprocess, 560.1ms inference, 53.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 625.5ms
# Speed: 2.5ms preprocess, 625.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 610.4ms
# Speed: 2.4ms preprocess, 610.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 551.9ms
# Speed: 2.4ms preprocess, 551.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 559.3ms
# Speed: 2.5ms preprocess, 559.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 631.6ms
# Speed: 2.3ms preprocess, 631.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 611.2ms
# Speed: 2.5ms preprocess, 611.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 604.3ms
# Speed: 2.4ms preprocess, 604.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 555.9ms
# Speed: 2.4ms preprocess, 555.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 557.0ms
# Speed: 2.4ms preprocess, 557.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 560.0ms
# Speed: 2.5ms preprocess, 560.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 556.2ms
# Speed: 2.5ms preprocess, 556.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 563.8ms
# Speed: 2.4ms preprocess, 563.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 625.8ms
# Speed: 2.4ms preprocess, 625.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 606.1ms
# Speed: 2.3ms preprocess, 606.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 567.8ms
# Speed: 2.5ms preprocess, 567.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 620.4ms
# Speed: 2.6ms preprocess, 620.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 533.5ms
# Speed: 2.6ms preprocess, 533.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 543.4ms
# Speed: 2.5ms preprocess, 543.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 549.8ms
# Speed: 2.4ms preprocess, 549.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 547.8ms
# Speed: 2.6ms preprocess, 547.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 607.6ms
# Speed: 2.4ms preprocess, 607.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 629.1ms
# Speed: 2.3ms preprocess, 629.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 586.5ms
# Speed: 2.5ms preprocess, 586.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 608.0ms
# Speed: 2.4ms preprocess, 608.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 624.1ms
# Speed: 2.5ms preprocess, 624.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 635.5ms
# Speed: 2.4ms preprocess, 635.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 577.8ms
# Speed: 2.2ms preprocess, 577.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 fire hydrant, 550.5ms
# Speed: 2.4ms preprocess, 550.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 537.1ms
# Speed: 2.4ms preprocess, 537.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 630.3ms
# Speed: 2.5ms preprocess, 630.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 583.3ms
# Speed: 2.4ms preprocess, 583.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 614.2ms
# Speed: 2.4ms preprocess, 614.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 625.4ms
# Speed: 2.5ms preprocess, 625.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed 200/538 frames.
#
# 0: 384x640 4 cars, 1 truck, 633.5ms
# Speed: 2.4ms preprocess, 633.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 571.0ms
# Speed: 2.4ms preprocess, 571.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 572.2ms
# Speed: 2.4ms preprocess, 572.2ms inference, 55.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 626.9ms
# Speed: 2.4ms preprocess, 626.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 536.4ms
# Speed: 2.5ms preprocess, 536.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 479.6ms
# Speed: 2.4ms preprocess, 479.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 483.0ms
# Speed: 2.3ms preprocess, 483.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 546.6ms
# Speed: 2.5ms preprocess, 546.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 494.8ms
# Speed: 2.3ms preprocess, 494.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 544.7ms
# Speed: 2.6ms preprocess, 544.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 536.0ms
# Speed: 2.4ms preprocess, 536.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 559.0ms
# Speed: 2.6ms preprocess, 559.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 538.4ms
# Speed: 2.3ms preprocess, 538.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 532.5ms
# Speed: 2.4ms preprocess, 532.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 534.6ms
# Speed: 2.5ms preprocess, 534.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 611.2ms
# Speed: 2.3ms preprocess, 611.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 642.9ms
# Speed: 2.5ms preprocess, 642.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 557.9ms
# Speed: 2.4ms preprocess, 557.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 546.5ms
# Speed: 2.3ms preprocess, 546.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 558.4ms
# Speed: 2.5ms preprocess, 558.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 501.8ms
# Speed: 2.3ms preprocess, 501.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 549.2ms
# Speed: 2.4ms preprocess, 549.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 607.7ms
# Speed: 2.3ms preprocess, 607.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 548.1ms
# Speed: 2.4ms preprocess, 548.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 546.1ms
# Speed: 2.4ms preprocess, 546.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 542.3ms
# Speed: 2.3ms preprocess, 542.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 546.6ms
# Speed: 2.5ms preprocess, 546.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 537.5ms
# Speed: 2.3ms preprocess, 537.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 591.8ms
# Speed: 2.4ms preprocess, 591.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 541.6ms
# Speed: 2.5ms preprocess, 541.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 600.4ms
# Speed: 2.5ms preprocess, 600.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 543.3ms
# Speed: 2.3ms preprocess, 543.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 562.3ms
# Speed: 2.5ms preprocess, 562.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 550.3ms
# Speed: 2.6ms preprocess, 550.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 555.5ms
# Speed: 2.5ms preprocess, 555.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 563.2ms
# Speed: 3.2ms preprocess, 563.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 560.1ms
# Speed: 2.4ms preprocess, 560.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 557.4ms
# Speed: 2.5ms preprocess, 557.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 546.8ms
# Speed: 2.4ms preprocess, 546.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 536.0ms
# Speed: 2.3ms preprocess, 536.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 527.6ms
# Speed: 2.3ms preprocess, 527.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 478.3ms
# Speed: 2.3ms preprocess, 478.3ms inference, 53.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 547.3ms
# Speed: 2.6ms preprocess, 547.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 483.0ms
# Speed: 2.3ms preprocess, 483.0ms inference, 54.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 542.0ms
# Speed: 2.3ms preprocess, 542.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 538.0ms
# Speed: 2.3ms preprocess, 538.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 535.4ms
# Speed: 2.3ms preprocess, 535.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 546.1ms
# Speed: 2.5ms preprocess, 546.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 531.1ms
# Speed: 2.4ms preprocess, 531.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 539.6ms
# Speed: 2.6ms preprocess, 539.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 547.7ms
# Speed: 2.3ms preprocess, 547.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 621.3ms
# Speed: 2.4ms preprocess, 621.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 614.1ms
# Speed: 2.5ms preprocess, 614.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 614.0ms
# Speed: 2.4ms preprocess, 614.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 540.3ms
# Speed: 2.5ms preprocess, 540.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 540.9ms
# Speed: 2.4ms preprocess, 540.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 544.7ms
# Speed: 2.4ms preprocess, 544.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 556.6ms
# Speed: 2.5ms preprocess, 556.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 550.5ms
# Speed: 2.3ms preprocess, 550.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 533.9ms
# Speed: 2.5ms preprocess, 533.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 527.6ms
# Speed: 2.3ms preprocess, 527.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 607.6ms
# Speed: 2.6ms preprocess, 607.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 536.5ms
# Speed: 2.5ms preprocess, 536.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 593.1ms
# Speed: 2.3ms preprocess, 593.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 536.0ms
# Speed: 2.7ms preprocess, 536.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 601.3ms
# Speed: 2.2ms preprocess, 601.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 541.4ms
# Speed: 2.4ms preprocess, 541.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 538.8ms
# Speed: 2.5ms preprocess, 538.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 548.6ms
# Speed: 2.2ms preprocess, 548.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 566.9ms
# Speed: 2.4ms preprocess, 566.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 568.9ms
# Speed: 2.3ms preprocess, 568.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 561.8ms
# Speed: 2.5ms preprocess, 561.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 553.0ms
# Speed: 2.4ms preprocess, 553.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 573.7ms
# Speed: 2.3ms preprocess, 573.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 547.0ms
# Speed: 2.3ms preprocess, 547.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 534.2ms
# Speed: 2.3ms preprocess, 534.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 532.8ms
# Speed: 2.5ms preprocess, 532.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 543.9ms
# Speed: 2.2ms preprocess, 543.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 597.9ms
# Speed: 2.3ms preprocess, 597.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 544.5ms
# Speed: 2.3ms preprocess, 544.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 552.6ms
# Speed: 2.6ms preprocess, 552.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 597.6ms
# Speed: 2.4ms preprocess, 597.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 538.3ms
# Speed: 2.3ms preprocess, 538.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 523.3ms
# Speed: 2.4ms preprocess, 523.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 541.3ms
# Speed: 2.5ms preprocess, 541.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 547.7ms
# Speed: 2.6ms preprocess, 547.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 561.3ms
# Speed: 2.6ms preprocess, 561.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 618.5ms
# Speed: 2.5ms preprocess, 618.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 629.6ms
# Speed: 3.9ms preprocess, 629.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 600.3ms
# Speed: 3.6ms preprocess, 600.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 618.3ms
# Speed: 2.6ms preprocess, 618.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 555.5ms
# Speed: 2.6ms preprocess, 555.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 1 fire hydrant, 564.4ms
# Speed: 3.7ms preprocess, 564.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 1 fire hydrant, 621.6ms
# Speed: 3.5ms preprocess, 621.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 547.2ms
# Speed: 2.6ms preprocess, 547.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 1 fire hydrant, 482.6ms
# Speed: 2.8ms preprocess, 482.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 559.7ms
# Speed: 3.6ms preprocess, 559.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 1 fire hydrant, 554.8ms
# Speed: 3.6ms preprocess, 554.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 547.2ms
# Speed: 2.7ms preprocess, 547.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 604.1ms
# Speed: 2.6ms preprocess, 604.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed 300/538 frames.
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 619.0ms
# Speed: 3.7ms preprocess, 619.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 612.9ms
# Speed: 3.6ms preprocess, 612.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 594.1ms
# Speed: 2.6ms preprocess, 594.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 613.2ms
# Speed: 2.5ms preprocess, 613.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 628.3ms
# Speed: 3.6ms preprocess, 628.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 633.6ms
# Speed: 4.0ms preprocess, 633.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 564.9ms
# Speed: 2.6ms preprocess, 564.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 546.9ms
# Speed: 2.8ms preprocess, 546.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 619.5ms
# Speed: 3.6ms preprocess, 619.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 608.0ms
# Speed: 3.9ms preprocess, 608.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 610.1ms
# Speed: 2.9ms preprocess, 610.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 545.0ms
# Speed: 2.6ms preprocess, 545.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 544.3ms
# Speed: 3.7ms preprocess, 544.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 613.6ms
# Speed: 3.6ms preprocess, 613.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 521.5ms
# Speed: 2.6ms preprocess, 521.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 474.7ms
# Speed: 2.5ms preprocess, 474.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 575.3ms
# Speed: 3.8ms preprocess, 575.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 624.0ms
# Speed: 3.5ms preprocess, 624.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 556.1ms
# Speed: 2.9ms preprocess, 556.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 537.0ms
# Speed: 2.4ms preprocess, 537.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 625.5ms
# Speed: 3.9ms preprocess, 625.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 568.5ms
# Speed: 3.7ms preprocess, 568.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 571.3ms
# Speed: 2.7ms preprocess, 571.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 556.4ms
# Speed: 2.5ms preprocess, 556.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 560.6ms
# Speed: 2.4ms preprocess, 560.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 543.1ms
# Speed: 2.4ms preprocess, 543.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 540.2ms
# Speed: 2.2ms preprocess, 540.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 550.4ms
# Speed: 2.4ms preprocess, 550.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 550.2ms
# Speed: 2.3ms preprocess, 550.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 531.4ms
# Speed: 2.3ms preprocess, 531.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 532.2ms
# Speed: 2.4ms preprocess, 532.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 534.1ms
# Speed: 2.2ms preprocess, 534.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 537.4ms
# Speed: 2.4ms preprocess, 537.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 555.8ms
# Speed: 2.6ms preprocess, 555.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 542.3ms
# Speed: 2.2ms preprocess, 542.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 530.8ms
# Speed: 2.3ms preprocess, 530.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 524.0ms
# Speed: 2.3ms preprocess, 524.0ms inference, 54.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 550.8ms
# Speed: 2.5ms preprocess, 550.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 2 cars, 1 truck, 541.9ms
# Speed: 2.3ms preprocess, 541.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 540.3ms
# Speed: 2.3ms preprocess, 540.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 605.3ms
# Speed: 2.4ms preprocess, 605.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 550.7ms
# Speed: 2.3ms preprocess, 550.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 527.3ms
# Speed: 2.3ms preprocess, 527.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 545.4ms
# Speed: 2.6ms preprocess, 545.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 598.1ms
# Speed: 2.3ms preprocess, 598.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 520.6ms
# Speed: 2.6ms preprocess, 520.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 533.2ms
# Speed: 2.4ms preprocess, 533.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 609.8ms
# Speed: 2.4ms preprocess, 609.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 627.9ms
# Speed: 2.5ms preprocess, 627.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 584.2ms
# Speed: 2.5ms preprocess, 584.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 604.7ms
# Speed: 2.7ms preprocess, 604.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 549.1ms
# Speed: 2.5ms preprocess, 549.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 538.7ms
# Speed: 2.4ms preprocess, 538.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 535.0ms
# Speed: 2.4ms preprocess, 535.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 529.9ms
# Speed: 2.4ms preprocess, 529.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 542.5ms
# Speed: 2.5ms preprocess, 542.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 552.3ms
# Speed: 2.5ms preprocess, 552.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 533.3ms
# Speed: 2.4ms preprocess, 533.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 525.5ms
# Speed: 2.3ms preprocess, 525.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 523.8ms
# Speed: 2.5ms preprocess, 523.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 531.0ms
# Speed: 2.4ms preprocess, 531.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 515.3ms
# Speed: 2.5ms preprocess, 515.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 488.9ms
# Speed: 2.4ms preprocess, 488.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 551.1ms
# Speed: 2.3ms preprocess, 551.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 537.7ms
# Speed: 2.6ms preprocess, 537.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 557.3ms
# Speed: 2.3ms preprocess, 557.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 594.6ms
# Speed: 2.5ms preprocess, 594.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 624.3ms
# Speed: 2.4ms preprocess, 624.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 551.3ms
# Speed: 2.4ms preprocess, 551.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 602.6ms
# Speed: 2.5ms preprocess, 602.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 532.3ms
# Speed: 2.3ms preprocess, 532.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 535.3ms
# Speed: 2.4ms preprocess, 535.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 481.3ms
# Speed: 2.6ms preprocess, 481.3ms inference, 55.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 537.9ms
# Speed: 2.3ms preprocess, 537.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 601.1ms
# Speed: 2.4ms preprocess, 601.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 528.4ms
# Speed: 2.5ms preprocess, 528.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 533.9ms
# Speed: 2.4ms preprocess, 533.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 476.9ms
# Speed: 2.4ms preprocess, 476.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 528.7ms
# Speed: 2.4ms preprocess, 528.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 545.6ms
# Speed: 2.4ms preprocess, 545.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 554.6ms
# Speed: 2.4ms preprocess, 554.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 588.8ms
# Speed: 2.3ms preprocess, 588.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 540.1ms
# Speed: 2.5ms preprocess, 540.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 566.1ms
# Speed: 2.5ms preprocess, 566.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 624.8ms
# Speed: 2.3ms preprocess, 624.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 553.9ms
# Speed: 2.6ms preprocess, 553.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 606.1ms
# Speed: 2.5ms preprocess, 606.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 534.7ms
# Speed: 2.4ms preprocess, 534.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 593.3ms
# Speed: 2.4ms preprocess, 593.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 548.9ms
# Speed: 2.5ms preprocess, 548.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 473.7ms
# Speed: 2.4ms preprocess, 473.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 525.9ms
# Speed: 2.4ms preprocess, 525.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 532.4ms
# Speed: 2.3ms preprocess, 532.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 548.5ms
# Speed: 2.3ms preprocess, 548.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 538.0ms
# Speed: 2.4ms preprocess, 538.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 538.9ms
# Speed: 2.3ms preprocess, 538.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 479.0ms
# Speed: 2.5ms preprocess, 479.0ms inference, 53.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 531.4ms
# Speed: 2.3ms preprocess, 531.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 529.7ms
# Speed: 2.3ms preprocess, 529.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 529.5ms
# Speed: 2.2ms preprocess, 529.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 554.6ms
# Speed: 2.4ms preprocess, 554.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 612.5ms
# Speed: 2.2ms preprocess, 612.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 612.7ms
# Speed: 2.3ms preprocess, 612.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 628.2ms
# Speed: 2.4ms preprocess, 628.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 597.8ms
# Speed: 2.4ms preprocess, 597.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 612.5ms
# Speed: 2.5ms preprocess, 612.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 528.9ms
# Speed: 2.4ms preprocess, 528.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 530.5ms
# Speed: 2.4ms preprocess, 530.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 500.6ms
# Speed: 2.3ms preprocess, 500.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 536.1ms
# Speed: 2.5ms preprocess, 536.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 533.5ms
# Speed: 2.5ms preprocess, 533.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 543.9ms
# Speed: 2.4ms preprocess, 543.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 469.1ms
# Speed: 2.5ms preprocess, 469.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 480.0ms
# Speed: 2.2ms preprocess, 480.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 532.4ms
# Speed: 2.3ms preprocess, 532.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 545.2ms
# Speed: 2.4ms preprocess, 545.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 524.1ms
# Speed: 2.3ms preprocess, 524.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 536.9ms
# Speed: 2.3ms preprocess, 536.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 539.4ms
# Speed: 2.6ms preprocess, 539.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 557.3ms
# Speed: 2.3ms preprocess, 557.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed 500/538 frames.
#
# 0: 384x640 2 cars, 1 truck, 624.9ms
# Speed: 2.5ms preprocess, 624.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 566.5ms
# Speed: 2.7ms preprocess, 566.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 541.5ms
# Speed: 2.5ms preprocess, 541.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 552.7ms
# Speed: 2.4ms preprocess, 552.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 534.3ms
# Speed: 2.5ms preprocess, 534.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 532.7ms
# Speed: 2.2ms preprocess, 532.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 535.4ms
# Speed: 2.4ms preprocess, 535.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 538.8ms
# Speed: 2.6ms preprocess, 538.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 609.4ms
# Speed: 2.4ms preprocess, 609.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 543.9ms
# Speed: 2.6ms preprocess, 543.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 524.2ms
# Speed: 2.4ms preprocess, 524.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 534.5ms
# Speed: 2.5ms preprocess, 534.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 533.9ms
# Speed: 2.5ms preprocess, 533.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 583.9ms
# Speed: 2.4ms preprocess, 583.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 534.6ms
# Speed: 2.3ms preprocess, 534.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 608.1ms
# Speed: 2.5ms preprocess, 608.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 534.1ms
# Speed: 2.4ms preprocess, 534.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 526.0ms
# Speed: 2.4ms preprocess, 526.0ms inference, 52.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 615.7ms
# Speed: 2.6ms preprocess, 615.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 545.2ms
# Speed: 2.7ms preprocess, 545.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 547.0ms
# Speed: 2.6ms preprocess, 547.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 615.1ms
# Speed: 2.5ms preprocess, 615.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 552.5ms
# Speed: 2.6ms preprocess, 552.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 467.8ms
# Speed: 2.5ms preprocess, 467.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 570.4ms
# Speed: 2.4ms preprocess, 570.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 599.6ms
# Speed: 2.5ms preprocess, 599.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 532.9ms
# Speed: 2.4ms preprocess, 532.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 538.9ms
# Speed: 2.5ms preprocess, 538.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 540.5ms
# Speed: 2.3ms preprocess, 540.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 534.6ms
# Speed: 2.2ms preprocess, 534.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 530.7ms
# Speed: 2.5ms preprocess, 530.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 537.0ms
# Speed: 2.4ms preprocess, 537.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 532.1ms
# Speed: 2.5ms preprocess, 532.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 527.6ms
# Speed: 2.6ms preprocess, 527.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 514.4ms
# Speed: 2.3ms preprocess, 514.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 537.8ms
# Speed: 2.4ms preprocess, 537.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 576.8ms
# Speed: 2.5ms preprocess, 576.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 550.0ms
# Speed: 2.5ms preprocess, 550.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing complete.

# %% [markdown]
# #8. Creating a Download Link for the Output Video

# %% [markdown]
# After processing, a download link i generated to retrieve the annotated video

# %%
# Function to create a download link in Colab
def create_download_link(filename, title="Download Video"):
    from IPython.display import HTML
    import urllib

    if not os.path.exists(filename):
        print(f"File {filename} does not exist.")
        return

    # Encode the file to be URL-safe
    encoded = urllib.parse.quote(filename)
    href = f'<a href="{encoded}" download="{os.path.basename(filename)}">{title}</a>'
    return HTML(href)

# Display the download link
create_download_link(output_video_path)
# Out:
# <a href="/content/vehicle-counting-annotated.mp4" download="vehicle-counting-annotated.mp4">Download Video</a>

# %% [markdown]
# # The final annotated video has successfully detected, tracked and counted all the cars and trucks: the dedicated IDs for each vehicle is also consistent throughout the video, further showcasing the yolov11x's capability to perform complete Computer Vision project with built-in tools and libraries.
