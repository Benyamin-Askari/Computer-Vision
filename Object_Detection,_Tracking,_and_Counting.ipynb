# %% [markdown]
# <a href="https://colab.research.google.com/github/Benyamin-Askari/Computer-Vision/blob/main/Object_Detection%2C_Tracking%2C_and_Counting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Install Necessary Packages

# %%
# Install necessary packages
# !pip install ultralytics
# !pip install opencv-python
# !pip install ffmpeg-python
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.48-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.13-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.48-py3-none-any.whl (898 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.8/898.8 kB 24.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.13-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.48 ultralytics-thop-2.0.13
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python) (1.0.0)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Installing collected packages: ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0

# %% [markdown]
# #2. Importing Libraries and Initializing the Model

# %% [markdown]
# Note:
#
# the below cell is to confirm that which Class ID corresponds to car to truck

# %%
from ultralytics import YOLO
import cv2
from google.colab import files
import os
from collections import deque

# Load the YOLO model
model = YOLO("yolo11x.pt")

# Verify class names and IDs
print("Model Classes and IDs:")
for class_id, class_name in model.names.items():
    print(f"ID {class_id}: {class_name}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11x.pt to 'yolo11x.pt'...
# 100%|██████████| 109M/109M [00:00<00:00, 351MB/s]
# Model Classes and IDs:
# ID 0: person
# ID 1: bicycle
# ID 2: car
# ID 3: motorcycle
# ID 4: airplane
# ID 5: bus
# ID 6: train
# ID 7: truck
# ID 8: boat
# ID 9: traffic light
# ID 10: fire hydrant
# ID 11: stop sign
# ID 12: parking meter
# ID 13: bench
# ID 14: bird
# ID 15: cat
# ID 16: dog
# ID 17: horse
# ID 18: sheep
# ID 19: cow
# ID 20: elephant
# ID 21: bear
# ID 22: zebra
# ID 23: giraffe
# ID 24: backpack
# ID 25: umbrella
# ID 26: handbag
# ID 27: tie
# ID 28: suitcase
# ID 29: frisbee
# ID 30: skis
# ID 31: snowboard
# ID 32: sports ball
# ID 33: kite
# ID 34: baseball bat
# ID 35: baseball glove
# ID 36: skateboard
# ID 37: surfboard
# ID 38: tennis racket
# ID 39: bottle
# ID 40: wine glass
# ID 41: cup
# ID 42: fork
# ID 43: knife
# ID 44: spoon
# ID 45: bowl
# ID 46: banana
# ID 47: apple
# ID 48: sandwich
# ID 49: orange
# ID 50: broccoli
# ID 51: carrot
# ID 52: hot dog
# ID 53: pizza
# ID 54: donut
# ID 55: cake
# ID 56: chair
# ID 57: couch
# ID 58: potted plant
# ID 59: bed
# ID 60: dining table
# ID 61: toilet
# ID 62: tv
# ID 63: laptop
# ID 64: mouse
# ID 65: remote
# ID 66: keyboard
# ID 67: cell phone
# ID 68: microwave
# ID 69: oven
# ID 70: toaster
# ID 71: sink
# ID 72: refrigerator
# ID 73: book
# ID 74: clock
# ID 75: vase
# ID 76: scissors
# ID 77: teddy bear
# ID 78: hair drier
# ID 79: toothbrush

# %% [markdown]
# Class ID "2" belongs to car and Class ID "7" belongs to truck

# %% [markdown]
# #3. Set Input and Output Video Paths

# %% [markdown]
# Specifying the paths to the input and output videos

# %%
# Path to the input video
input_video_path = "/content/vehicle-counting.mp4"

# Path to the output video
output_video_path = "/content/vehicle-counting-annotated.mp4"

# %% [markdown]
# #4. Initialize Video Capture and Writer

# %% [markdown]
# Setting up video capture for reading, and video writer for saving the annotated video

# %%
# Create a Video Capture Object
cap = cv2.VideoCapture(input_video_path)

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))


# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # 'mp4v' is generally reliable for MP4
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# %% [markdown]
# #5. Initialize Counters and Tracking Structures

# %% [markdown]
# Setting up counters for categorizing counter based on direction and vehicle type

# %%
# Initialize vehicle counters and line information
car_count_in = 0
car_count_out = 0
truck_count_in = 0
truck_count_out = 0
line_position = None

# Store tracked object IDs and their previous positions
crossed_ids = set()
track_positions = {}

# %% [markdown]
# #6. Define Helper Functions

# %% [markdown]
# Implementing the functions to draw the counting line, determining movement direction, and filtering desired classes based on class IDs (cars and trucks in this case)

# %%
# Function to draw the counting line
def draw_counting_line(frame):
    global line_position
    height, width = frame.shape[:2]
    if line_position is None:  # Set the line position only once
        line_position = height - 400  # Line 400 pixels from the bottom
    cv2.line(frame, (0, line_position), (width, line_position), (0, 255, 0), 2)

# Function to determine direction
def get_direction(track_id, current_center_y):
    previous_center_y = track_positions.get(track_id, None)
    if previous_center_y is None:
        return None  # Not enough information to determine direction
    if previous_center_y < line_position and current_center_y > line_position:
        return "down"  # Moving downwards (e.g., Out)
    elif previous_center_y > line_position and current_center_y < line_position:
        return "up"    # Moving upwards (e.g., In)
    else:
        return None  # No crossing or moving parallel

# Function to check if the class ID is desired (2 for car, 7 for truck)
def is_desired_class_id(class_id):
    desired_class_ids = [2, 7]  # 2: car, 7: truck
    return class_id in desired_class_ids

# %% [markdown]
# #7. Processing Video Frames

# %% [markdown]
# This section processes each frame, performs detection and tracking: then updates counts based on direction, and finally, annotates the frames

# %%
# Process video frames
frame_number = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break  # End of video

    frame_number += 1

    # Draw the counting line
    draw_counting_line(frame)

    # Run YOLO detection with ByteTrack tracking
    results = model.track(
    source=frame,
    persist=True,
    tracker="bytetrack.yaml",
    conf=0.25,
    iou=0.5
)


    # Process each detection
    if results[0].boxes:  # Ensure there are detections
        for box in results[0].boxes:
            # Extract bounding box, class ID, and unique track ID
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            class_id = int(box.cls)
            track_id = int(box.id)

            # Skip unwanted classes based on class ID
            if not is_desired_class_id(class_id):
                continue  # Skip this detection

            # Get the center point of the bounding box
            center_x = (x1 + x2) // 2
            center_y = (y1 + y2) // 2

            # Determine direction based on previous position
            direction = get_direction(track_id, center_y)

            # Update the previous position
            track_positions[track_id] = center_y

            # Check if the object has crossed the line and hasn't been counted yet
            if track_id not in crossed_ids and direction is not None:
                crossed_ids.add(track_id)  # Mark object as counted
                if class_id == 2:  # Car
                    if direction == "down":
                        car_count_out += 1
                    elif direction == "up":
                        car_count_in += 1
                elif class_id == 7:  # Truck
                    if direction == "down":
                        truck_count_out += 1
                    elif direction == "up":
                        truck_count_in += 1

            # Assign class name based on class ID
            if class_id == 2:
                class_name = "Car"
                color = (255, 0, 0)  # Blue for cars
            elif class_id == 7:
                class_name = "Truck"
                color = (0, 0, 255)  # Red for trucks
            else:
                class_name = "Unknown"
                color = (0, 255, 255)  # Yellow for other desired classes

            # Draw bounding box and label on the frame
            label = f"{class_name} ID:{track_id}"
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, label, (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)

    # Display the vehicle counts on the frame
    cv2.putText(frame, f"Cars In: {car_count_in}", (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    cv2.putText(frame, f"Cars Out: {car_count_out}", (10, 70),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
    cv2.putText(frame, f"Trucks In: {truck_count_in}", (10, 110),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    cv2.putText(frame, f"Trucks Out: {truck_count_out}", (10, 150),
                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Write the annotated frame to the output video
    out.write(frame)


print("Processing complete.")

# Release video writer and capture
out.release()
cap.release()
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Collecting lap>=0.5.12
#   Downloading lap-0.5.12-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from lap>=0.5.12) (1.26.4)
# Downloading lap-0.5.12-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB
5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 61.8ms
# Speed: 3.7ms preprocess, 61.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 63.2ms
# Speed: 5.3ms preprocess, 63.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 63.2ms
# Speed: 3.7ms preprocess, 63.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 59.1ms
# Speed: 3.4ms preprocess, 59.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 49.2ms
# Speed: 6.4ms preprocess, 49.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 49.2ms
# Speed: 3.3ms preprocess, 49.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 49.2ms
# Speed: 3.3ms preprocess, 49.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 49.2ms
# Speed: 4.2ms preprocess, 49.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 47.4ms
# Speed: 3.3ms preprocess, 47.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 46.8ms
# Speed: 3.5ms preprocess, 46.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 45.6ms
# Speed: 3.2ms preprocess, 45.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 45.6ms
# Speed: 3.4ms preprocess, 45.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 45.6ms
# Speed: 3.4ms preprocess, 45.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 45.6ms
# Speed: 3.2ms preprocess, 45.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 45.6ms
# Speed: 3.4ms preprocess, 45.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 40.9ms
# Speed: 3.3ms preprocess, 40.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 40.5ms
# Speed: 3.4ms preprocess, 40.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 40.5ms
# Speed: 3.4ms preprocess, 40.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 40.5ms
# Speed: 3.3ms preprocess, 40.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 46.6ms
# Speed: 4.2ms preprocess, 46.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 47.9ms
# Speed: 3.6ms preprocess, 47.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 39.5ms
# Speed: 4.1ms preprocess, 39.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 39.5ms
# Speed: 3.3ms preprocess, 39.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 39.5ms
# Speed: 3.4ms preprocess, 39.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 39.5ms
# Speed: 3.6ms preprocess, 39.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 39.5ms
# Speed: 3.4ms preprocess, 39.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 39.5ms
# Speed: 3.4ms preprocess, 39.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 39.5ms
# Speed: 5.6ms preprocess, 39.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 39.5ms
# Speed: 9.4ms preprocess, 39.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 1 fire hydrant, 39.4ms
# Speed: 4.2ms preprocess, 39.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 39.6ms
# Speed: 3.4ms preprocess, 39.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 39.5ms
# Speed: 3.5ms preprocess, 39.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 42.0ms
# Speed: 3.3ms preprocess, 42.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 41.1ms
# Speed: 4.6ms preprocess, 41.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 41.8ms
# Speed: 3.0ms preprocess, 41.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 43.2ms
# Speed: 3.7ms preprocess, 43.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 43.2ms
# Speed: 3.4ms preprocess, 43.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 43.2ms
# Speed: 3.4ms preprocess, 43.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 44.3ms
# Speed: 3.4ms preprocess, 44.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 44.6ms
# Speed: 5.2ms preprocess, 44.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 65.6ms
# Speed: 4.1ms preprocess, 65.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 45.0ms
# Speed: 3.5ms preprocess, 45.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 48.7ms
# Speed: 7.4ms preprocess, 48.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 46.9ms
# Speed: 3.4ms preprocess, 46.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 42.0ms
# Speed: 3.3ms preprocess, 42.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 40.5ms
# Speed: 10.1ms preprocess, 40.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 40.5ms
# Speed: 3.3ms preprocess, 40.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 40.5ms
# Speed: 3.4ms preprocess, 40.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 40.5ms
# Speed: 3.4ms preprocess, 40.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 40.5ms
# Speed: 4.0ms preprocess, 40.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 40.5ms
# Speed: 4.8ms preprocess, 40.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 1 fire hydrant, 40.5ms
# Speed: 3.5ms preprocess, 40.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 1 fire hydrant, 40.5ms
# Speed: 3.4ms preprocess, 40.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 40.5ms
# Speed: 3.2ms preprocess, 40.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 1 fire hydrant, 52.2ms
# Speed: 3.2ms preprocess, 52.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 40.5ms
# Speed: 3.4ms preprocess, 40.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 1 fire hydrant, 47.5ms
# Speed: 3.3ms preprocess, 47.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 43.7ms
# Speed: 3.4ms preprocess, 43.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 44.3ms
# Speed: 3.3ms preprocess, 44.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 44.6ms
# Speed: 5.1ms preprocess, 44.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 45.0ms
# Speed: 4.1ms preprocess, 45.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 46.1ms
# Speed: 3.7ms preprocess, 46.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 47.0ms
# Speed: 4.2ms preprocess, 47.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 46.9ms
# Speed: 3.2ms preprocess, 46.9ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 41.3ms
# Speed: 3.5ms preprocess, 41.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 40.5ms
# Speed: 3.5ms preprocess, 40.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 40.5ms
# Speed: 3.4ms preprocess, 40.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 1 fire hydrant, 40.5ms
# Speed: 3.4ms preprocess, 40.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 39.6ms
# Speed: 3.6ms preprocess, 39.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 39.5ms
# Speed: 3.5ms preprocess, 39.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 39.5ms
# Speed: 3.6ms preprocess, 39.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 42.0ms
# Speed: 3.4ms preprocess, 42.0ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 39.5ms
# Speed: 3.3ms preprocess, 39.5ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 40.0ms
# Speed: 3.7ms preprocess, 40.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 39.5ms
# Speed: 8.7ms preprocess, 39.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 50.4ms
# Speed: 3.9ms preprocess, 50.4ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 40.9ms
# Speed: 3.5ms preprocess, 40.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 39.7ms
# Speed: 7.7ms preprocess, 39.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 44.3ms
# Speed: 6.5ms preprocess, 44.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 51.9ms
# Speed: 3.3ms preprocess, 51.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 67.5ms
# Speed: 3.5ms preprocess, 67.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 53.8ms
# Speed: 5.2ms preprocess, 53.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 50.1ms
# Speed: 3.4ms preprocess, 50.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 53.4ms
# Speed: 6.4ms preprocess, 53.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 53.5ms
# Speed: 3.4ms preprocess, 53.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 53.7ms
# Speed: 3.7ms preprocess, 53.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 55
ms preprocess, 40.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 40.9ms
# Speed: 3.4ms preprocess, 40.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 40.1ms
# Speed: 3.6ms preprocess, 40.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 40.0ms
# Speed: 3.2ms preprocess, 40.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 40.1ms
# Speed: 5.8ms preprocess, 40.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 44.6ms
# Speed: 4.2ms preprocess, 44.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 40.1ms
# Speed: 3.4ms preprocess, 40.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 48.5ms
# Speed: 5.4ms preprocess, 48.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 40.7ms
# Speed: 6.4ms preprocess, 40.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 49.1ms
# Speed: 3.3ms preprocess, 49.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 47.7ms
# Speed: 11.3ms preprocess, 47.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 49.2ms
# Speed: 5.3ms preprocess, 49.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 50.9ms
# Speed: 3.4ms preprocess, 50.9ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 51.8ms
# Speed: 5.0ms preprocess, 51.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 53.7ms
# Speed: 3.8ms preprocess, 53.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 61.0ms
# Speed: 3.8ms preprocess, 61.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 55.7ms
# Speed: 9.3ms preprocess, 55.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 60.1ms
# Speed: 4.0ms preprocess, 60.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 59.2ms
# Speed: 3.3ms preprocess, 59.2ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 60.5ms
# Speed: 7.3ms preprocess, 60.5ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 62.7ms
# Speed: 4.8ms preprocess, 62.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 69.5ms
# Speed: 3.2ms preprocess, 69.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 63.2ms
# Speed: 3.6ms preprocess, 63.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 63.2ms
# Speed: 3.3ms preprocess, 63.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 58.8ms
# Speed: 3.4ms preprocess, 58.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 51.8ms
# Speed: 3.3ms preprocess, 51.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 51.8ms
# Speed: 3.4ms preprocess, 51.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 51.8ms
# Speed: 7.1ms preprocess, 51.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 51.8ms
# Speed: 3.3ms preprocess, 51.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 44.5ms
# Speed: 4.1ms preprocess, 44.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 44.5ms
# Speed: 3.3ms preprocess, 44.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 44.5ms
# Speed: 4.4ms preprocess, 44.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 47.4ms
# Speed: 3.5ms preprocess, 47.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 44.5ms
# Speed: 3.7ms preprocess, 44.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 44.5ms
# Speed: 3.3ms preprocess, 44.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 44.4ms
# Speed: 3.2ms preprocess, 44.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 44.0ms
# Speed: 3.1ms preprocess, 44.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 44.0ms
# Speed: 3.2ms preprocess, 44.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 43.9ms
# Speed: 3.4ms preprocess, 43.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.2ms
# Speed: 3.3ms preprocess, 41.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 47.6ms
# Speed: 3.2ms preprocess, 47.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.0ms
# Speed: 5.8ms preprocess, 41.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.0ms
# Speed: 5.7ms preprocess, 41.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.0ms
# Speed: 4.1ms preprocess, 41.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.0ms
# Speed: 3.0ms preprocess, 41.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.0ms
# Speed: 3.4ms preprocess, 41.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.0ms
# Speed: 4.3ms preprocess, 41.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 41.0ms
# Speed: 3.3ms preprocess, 41.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.5ms
# Speed: 3.8ms preprocess, 39.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 43.0ms
# Speed: 6.0ms preprocess, 43.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.4ms
# Speed: 3.1ms preprocess, 39.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.5ms
# Speed: 4.6ms preprocess, 39.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.4ms
# Speed: 4.3ms preprocess, 39.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.9ms
# Speed: 3.4ms preprocess, 39.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.4ms
# Speed: 3.2ms preprocess, 39.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.5ms
# Speed: 4.9ms preprocess, 39.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing complete.

# %% [markdown]
# #8. Creating a Download Link for the Output Video

# %% [markdown]
# After processing, a download link is generated to retrieve the annotated video

# %%
# Function to create a download link in Colab
def create_download_link(filename, title="Download Video"):
    from IPython.display import HTML
    import urllib

    if not os.path.exists(filename):
        print(f"File {filename} does not exist.")
        return

    # Encode the file to be URL-safe
    encoded = urllib.parse.quote(filename)
    href = f'<a href="{encoded}" download="{os.path.basename(filename)}">{title}</a>'
    return HTML(href)

# Display the download link
create_download_link(output_video_path)
# Out:
# <a href="/content/vehicle-counting-annotated.mp4" download="vehicle-counting-annotated.mp4">Download Video</a>

# %% [markdown]
# # The final annotated video has successfully detected, tracked and counted all the cars and trucks: the dedicated IDs for each vehicle is also consistent throughout the video, further showcasing the yolov11x's capability to perform complete Computer Vision project with built-in tools and libraries.
